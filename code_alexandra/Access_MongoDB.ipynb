# %% [markdown]
# ## Load Stack Overflow Data from MongoDB Database

# %% [markdown]
# For this to work you need to place your MongoDB connection string as a .env file inside the same directory as the code (use for example TextEdit or Sublime Text). Inside the file there needs to be:
#
# CONNECTION_STRING=Your Personal connection string

# %%
## CODE DOES NOT WORK YET!!!

import os
from dotenv import load_dotenv,find_dotenv
from pymongo import MongoClient, UpdateOne
import pandas as pd

load_dotenv()
 
def get_collection(database, collection):
    # Provide the mongodb atlas url to connect python to mongodb using pymongo
    CONNECTION_STRING = os.getenv("CONNECTION_STRING")

    # Create a connection using MongoClient. You can import MongoClient or use pymongo.MongoClient
    client = MongoClient(CONNECTION_STRING)

    # Create the database for our example (we will use the same database throughout the tutorial
    return client["database"]["collection"]

# %%
stack_overflow = get_collection("stackoverflow", "stackoverflow")

# %%
pwd()
# Out:
# '/Users/alexandrarottenkolber/Documents/05_Spatial_Inequalities/The-Technology-Space-and-Digital-Development/code_alexandra'

# %%
client.get_database("stackoverflow")

db = client["stackoverflow"]

# %%
db.list_collection_names()
# Out:
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# File ~/opt/anaconda3/envs/spatial_inequ/lib/python3.10/site-packages/pymongo/pool.py:1394, in Pool._get_socket(self, all_credentials)
#    1393     with self.lock:
# -> 1394         sock_info = self.sockets.popleft()
#    1395 except IndexError:
#    1396     # Can raise ConnectionFailure or CertificateError.
#
# IndexError: pop from an empty deque
#
# During handling of the above exception, another exception occurred:
#
# OperationFailure                          Traceback (most recent call last)
# Input In [38], in <cell line: 1>()
# ----> 1 db.list_collection_names()
#
# File ~/opt/anaconda3/envs/spatial_inequ/lib/python3.10/site-packages/pymongo/database.py:880, in Database.list_collection_names(self, session, filter, **kwargs)
#     876     if not filter or (len(filter) == 1 and "name" in filter):
#     877         kwargs["nameOnly"] = True
#     879 return [result["name"]
# --> 880         for result in self.list_collections(session=session, **kwargs)]
#
# File ~/opt/anaconda3/envs/spatial_inequ/lib/python3.10/site-packages/pymongo/database.py:842, in Database.list_collections(self, session, filter, **kwargs)
#     837 def _cmd(session, server, sock_info, secondary_okay):
#     838     return self._list_collections(
#     839         sock_info, secondary_okay, session, read_preference=read_pref,
#     840         **kwargs)
# --> 842 return self.__client._retryable_read(
#     843     _cmd, read_pref, session)
#
# File ~/opt/anaconda3/envs/spatial_inequ/lib/python3.10/site-packages/pymongo/mongo_client.py:1518, in MongoClient._retryable_read(self, func, read_pref, session, address, retryable)
#    1516 if not server.description.retryable_reads_supported:
#    1517     retryable = False
# -> 1518 with self._secondaryok_for_server(
#    1519         read_pref, server, session) as (
#    1520                 sock_info, secondary_ok):
#    1521     if retrying and not retryable:
#    1522         # A retry is not possible because this server does
#    1523         # not support retryable reads, raise the last error.
#    1524         raise last_error
#
# File ~/opt/anaconda3/envs/spatial_inequ/lib/python3.10/contextlib.py:135, in _GeneratorContextManager.__enter__(self)
#     133 del self.args, self.kwds, self.func
#     134 try:
# --> 135     return next(self.gen)
#     136 except StopIteration:
#     137     raise RuntimeError("generator didn't yield") from None
#
# File ~/opt/anaconda3/envs/spatial_inequ/lib/python3.10/site-packages/pymongo/mongo_client.py:1371, in MongoClient._secondaryok_for_server(self, read_preference, server, session)
#    1368 topology = self._get_topology()
#    1369 single = topology.description.topology_type == TOPOLOGY_TYPE.Single
# -> 1371 with self._get_socket(server, session) as sock_info:
#    1372     secondary_ok = (single and not sock_info.is_mongos) or (
#    1373         read_preference != ReadPreference.PRIMARY)
#    1374     yield sock_info, secondary_ok
#
# File ~/opt/anaconda3/envs/spatial_inequ/lib/python3.10/contextlib.py:135, in _GeneratorContextManager.__enter__(self)
#     133 del self.args, self.kwds, self.func
#     134 try:
# --> 135     return next(self.gen)
#     136 except StopIteration:
#     137     raise RuntimeError("generator didn't yield") from None
#
# File ~/opt/anaconda3/envs/spatial_inequ/lib/python3.10/site-packages/pymongo/mongo_client.py:1308, in MongoClient._get_socket(self, server, session)
#    1306     yield session._pinned_connection
#    1307     return
# -> 1308 with server.get_socket(
#    1309         self.__all_credentials, handler=err_handler) as sock_info:
#    1310     # Pin this session to the selected server or connection.
#    1311     if (in_txn and server.description.server_type in (
#    1312             SERVER_TYPE.Mongos, SERVER_TYPE.LoadBalancer)):
#    1313         session._pin(server, sock_info)
#
# File ~/opt/anaconda3/envs/spatial_inequ/lib/python3.10/contextlib.py:135, in _GeneratorContextManager.__enter__(self)
#     133 del self.args, self.kwds, self.func
#     134 try:
# --> 135     return next(self.gen)
#     136 except StopIteration:
#     137     raise RuntimeError("generator didn't yield") from None
#
# File ~/opt/anaconda3/envs/spatial_inequ/lib/python3.10/site-packages/pymongo/pool.py:1331, in Pool.get_socket(self, all_credentials, handler)
#    1328 if self.enabled_for_cmap:
#    1329     listeners.publish_connection_check_out_started(self.address)
# -> 1331 sock_info = self._get_socket(all_credentials)
#    1332 if self.enabled_for_cmap:
#    1333     listeners.publish_connection_checked_out(
#    1334         self.address, sock_info.id)
#
# File ~/opt/anaconda3/envs/spatial_inequ/lib/python3.10/site-packages/pymongo/pool.py:1397, in Pool._get_socket(self, all_credentials)
#    1394         sock_info = self.sockets.popleft()
#    1395 except IndexError:
#    1396     # Can raise ConnectionFailure or CertificateError.
# -> 1397     sock_info = self.connect(all_credentials)
#    1398 else:
#    1399     if self._perished(sock_info):
#
# File ~/opt/anaconda3/envs/spatial_inequ/lib/python3.10/site-packages/pymongo/pool.py:1297, in Pool.connect(self, all_credentials)
#    1294         sock_info.hello(all_credentials)
#    1295         self.is_writable = sock_info.is_writable
# -> 1297     sock_info.check_auth(all_credentials)
#    1298 except BaseException:
#    1299     sock_info.close_socket(ConnectionClosedReason.ERROR)
#
# File ~/opt/anaconda3/envs/spatial_inequ/lib/python3.10/site-packages/pymongo/pool.py:820, in SocketInfo.check_auth(self, all_credentials)
#     817         self.authset.discard(credentials)
#     819     for credentials in cached - authset:
# --> 820         self.authenticate(credentials)
#     822 # CMAP spec says to publish the ready event only after authenticating
#     823 # the connection.
#     824 if not self.ready:
#
# File ~/opt/anaconda3/envs/spatial_inequ/lib/python3.10/site-packages/pymongo/pool.py:837, in SocketInfo.authenticate(self, credentials)
#     829 def authenticate(self, credentials):
#     830     """Log in to the server and store these credentials in `authset`.
#     831
#     832     Can raise ConnectionFailure or OperationFailure.
#    (...)
#     835       - `credentials`: A MongoCredential.
#     836     """
# --> 837     auth.authenticate(credentials, self)
#     838     self.authset.add(credentials)
#     839     # negotiated_mechanisms are no longer needed.
#
# File ~/opt/anaconda3/envs/spatial_inequ/lib/python3.10/site-packages/pymongo/auth.py:672, in authenticate(credentials, sock_info)
#     670 mechanism = credentials.mechanism
#     671 auth_func = _AUTH_MAP.get(mechanism)
# --> 672 auth_func(credentials, sock_info)
#
# File ~/opt/anaconda3/envs/spatial_inequ/lib/python3.10/site-packages/pymongo/auth.py:588, in _authenticate_default(credentials, sock_info)
#     584     mechs = sock_info.command(
#     585         source, cmd, publish_events=False).get(
#     586         'saslSupportedMechs', [])
#     587 if 'SCRAM-SHA-256' in mechs:
# --> 588     return _authenticate_scram(credentials, sock_info, 'SCRAM-SHA-256')
#     589 else:
#     590     return _authenticate_scram(credentials, sock_info, 'SCRAM-SHA-1')
#
# File ~/opt/anaconda3/envs/spatial_inequ/lib/python3.10/site-packages/pymongo/auth.py:333, in _authenticate_scram(credentials, sock_info, mechanism)
#     327 server_sig = standard_b64encode(
#     328     _hmac(server_key, auth_msg, digestmod).digest())
#     330 cmd = SON([('saslContinue', 1),
#     331            ('conversationId', res['conversationId']),
#     332            ('payload', Binary(client_final))])
# --> 333 res = sock_info.command(source, cmd)
#     335 parsed = _parse_scram_response(res['payload'])
#     336 if not compare_digest(parsed[b'v'], server_sig):
#
# File ~/opt/anaconda3/envs/spatial_inequ/lib/python3.10/site-packages/pymongo/pool.py:710, in SocketInfo.command(self, dbname, spec, secondary_ok, read_preference, codec_options, check, allowable_errors, check_keys, read_concern, write_concern, parse_write_concern_error, collation, session, client, retryable_write, publish_events, user_fields, exhaust_allowed)
#     708     self._raise_if_not_writable(unacknowledged)
#     709 try:
# --> 710     return command(self, dbname, spec, secondary_ok,
#     711                    self.is_mongos, read_preference, codec_options,
#     712                    session, client, check, allowable_errors,
#     713                    self.address, check_keys, listeners,
#     714                    self.max_bson_size, read_concern,
#     715                    parse_write_concern_error=parse_write_concern_error,
#     716                    collation=collation,
#     717                    compression_ctx=self.compression_context,
#     718                    use_op_msg=self.op_msg_enabled,
#     719                    unacknowledged=unacknowledged,
#     720                    user_fields=user_fields,
#     721                    exhaust_allowed=exhaust_allowed)
#     722 except (OperationFailure, NotPrimaryError):
#     723     raise
#
# File ~/opt/anaconda3/envs/spatial_inequ/lib/python3.10/site-packages/pymongo/network.py:158, in command(sock_info, dbname, spec, secondary_ok, is_mongos, read_preference, codec_options, session, client, check, allowable_errors, address, check_keys, listeners, max_bson_size, read_concern, parse_write_concern_error, collation, compression_ctx, use_op_msg, unacknowledged, user_fields, exhaust_allowed)
#     156             client._process_response(response_doc, session)
#     157         if check:
# --> 158             helpers._check_command_response(
#     159                 response_doc, sock_info.max_wire_version, allowable_errors,
#     160                 parse_write_concern_error=parse_write_concern_error)
#     161 except Exception as exc:
#     162     if publish:
#
# File ~/opt/anaconda3/envs/spatial_inequ/lib/python3.10/site-packages/pymongo/helpers.py:167, in _check_command_response(response, max_wire_version, allowable_errors, parse_write_concern_error)
#     164 elif code == 43:
#     165     raise CursorNotFound(errmsg, code, response, max_wire_version)
# --> 167 raise OperationFailure(errmsg, code, response, max_wire_version)
#
# OperationFailure: Authentication failed., full error: {'ok': 0.0, 'errmsg': 'Authentication failed.', 'code': 18, 'codeName': 'AuthenticationFailed'}

# %%
import pprint
pprint.pprint(posts.find_one())

# %%
for post in posts.find({"author": "Mike"}):
  pprint.pprint(post)

# %%
# Provide the mongodb atlas url to connect python to mongodb using pymongo
CONNECTION_STRING = os.getenv("CONNECTION_STRING")

# Create a connection using MongoClient. You can import MongoClient or use pymongo.MongoClient
client = MongoClient(CONNECTION_STRING)

# %%
client["database"]["collection"]["database"]["MongoClient"]
# Out:
# Collection(Database(MongoClient(host=['188.34.192.208:27017'], document_class=dict, tz_aware=False, connect=True, authsource='test', readpreference='primary', appname='MongoDB Compass', directconnection=True, ssl=False), 'database'), 'collection.database.MongoClient')

# %%
client["database"]
# Out:
# Database(MongoClient(host=['188.34.192.208:27017'], document_class=dict, tz_aware=False, connect=True, authsource='test', readpreference='primary', appname='MongoDB Compass', directconnection=True, ssl=False), 'database')

# %%
# Get all data 
cursor = stack_overflow.find({})

df = pd.DataFrame(list(cursor))
# Out:
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# File ~/opt/anaconda3/envs/spatial_inequ/lib/python3.10/site-packages/pymongo/pool.py:1394, in Pool._get_socket(self, all_credentials)
#    1393     with self.lock:
# -> 1394         sock_info = self.sockets.popleft()
#    1395 except IndexError:
#    1396     # Can raise ConnectionFailure or CertificateError.
#
# IndexError: pop from an empty deque
#
# During handling of the above exception, another exception occurred:
#
# OperationFailure                          Traceback (most recent call last)
# Input In [24], in <cell line: 4>()
#       1 # Get all data
#       2 cursor = stack_overflow.find({})
# ----> 4 df = pd.DataFrame(list(cursor))
#
# File ~/opt/anaconda3/envs/spatial_inequ/lib/python3.10/site-packages/pymongo/cursor.py:1238, in Cursor.next(self)
#    1236 if self.__empty:
#    1237     raise StopIteration
# -> 1238 if len(self.__data) or self._refresh():
#    1239     if self.__manipulate:
#    1240         _db = self.__collection.database
#
# File ~/opt/anaconda3/envs/spatial_inequ/lib/python3.10/site-packages/pymongo/cursor.py:1155, in Cursor._refresh(self)
#    1134         warnings.warn("using a min/max query operator without "
#    1135                       "specifying a Cursor.hint is deprecated. A "
#    1136                       "hint will be required when using min/max in "
#    1137                       "PyMongo 4.0",
#    1138                       DeprecationWarning, stacklevel=3)
#    1139     q = self._query_class(self.__query_flags,
#    1140                           self.__collection.database.name,
#    1141                           self.__collection.name,
#    (...)
#    1153                           self.__allow_disk_use,
#    1154                           self.__exhaust)
# -> 1155     self.__send_message(q)
#    1156 elif self.__id:  # Get More
#    1157     if self.__limit:
#
# File ~/opt/anaconda3/envs/spatial_inequ/lib/python3.10/site-packages/pymongo/cursor.py:1044, in Cursor.__send_message(self, operation)
#    1040     raise InvalidOperation(
#    1041         "exhaust cursors do not support auto encryption")
#    1043 try:
# -> 1044     response = client._run_operation(
#    1045         operation, self._unpack_response, address=self.__address)
#    1046 except OperationFailure as exc:
#    1047     if exc.code in _CURSOR_CLOSED_ERRORS or self.__exhaust:
#    1048         # Don't send killCursors because the cursor is already closed.
#
# File ~/opt/anaconda3/envs/spatial_inequ/lib/python3.10/site-packages/pymongo/mongo_client.py:1424, in MongoClient._run_operation(self, operation, unpack_res, address)
#    1419 def _cmd(session, server, sock_info, secondary_ok):
#    1420     return server.run_operation(
#    1421         sock_info, operation, secondary_ok, self._event_listeners,
#    1422         unpack_res)
# -> 1424 return self._retryable_read(
#    1425     _cmd, operation.read_preference, operation.session,
#    1426     address=address, retryable=isinstance(operation, message._Query))
#
# File ~/opt/anaconda3/envs/spatial_inequ/lib/python3.10/site-packages/pymongo/mongo_client.py:1518, in MongoClient._retryable_read(self, func, read_pref, session, address, retryable)
#    1516 if not server.description.retryable_reads_supported:
#    1517     retryable = False
# -> 1518 with self._secondaryok_for_server(
#    1519         read_pref, server, session) as (
#    1520                 sock_info, secondary_ok):
#    1521     if retrying and not retryable:
#    1522         # A retry is not possible because this server does
#    1523         # not support retryable reads, raise the last error.
#    1524         raise last_error
#
# File ~/opt/anaconda3/envs/spatial_inequ/lib/python3.10/contextlib.py:135, in _GeneratorContextManager.__enter__(self)
#     133 del self.args, self.kwds, self.func
#     134 try:
# --> 135     return next(self.gen)
#     136 except StopIteration:
#     137     raise RuntimeError("generator didn't yield") from None
#
# File ~/opt/anaconda3/envs/spatial_inequ/lib/python3.10/site-packages/pymongo/mongo_client.py:1371, in MongoClient._secondaryok_for_server(self, read_preference, server, session)
#    1368 topology = self._get_topology()
#    1369 single = topology.description.topology_type == TOPOLOGY_TYPE.Single
# -> 1371 with self._get_socket(server, session) as sock_info:
#    1372     secondary_ok = (single and not sock_info.is_mongos) or (
#    1373         read_preference != ReadPreference.PRIMARY)
#    1374     yield sock_info, secondary_ok
#
# File ~/opt/anaconda3/envs/spatial_inequ/lib/python3.10/contextlib.py:135, in _GeneratorContextManager.__enter__(self)
#     133 del self.args, self.kwds, self.func
#     134 try:
# --> 135     return next(self.gen)
#     136 except StopIteration:
#     137     raise RuntimeError("generator didn't yield") from None
#
# File ~/opt/anaconda3/envs/spatial_inequ/lib/python3.10/site-packages/pymongo/mongo_client.py:1308, in MongoClient._get_socket(self, server, session)
#    1306     yield session._pinned_connection
#    1307     return
# -> 1308 with server.get_socket(
#    1309         self.__all_credentials, handler=err_handler) as sock_info:
#    1310     # Pin this session to the selected server or connection.
#    1311     if (in_txn and server.description.server_type in (
#    1312             SERVER_TYPE.Mongos, SERVER_TYPE.LoadBalancer)):
#    1313         session._pin(server, sock_info)
#
# File ~/opt/anaconda3/envs/spatial_inequ/lib/python3.10/contextlib.py:135, in _GeneratorContextManager.__enter__(self)
#     133 del self.args, self.kwds, self.func
#     134 try:
# --> 135     return next(self.gen)
#     136 except StopIteration:
#     137     raise RuntimeError("generator didn't yield") from None
#
# File ~/opt/anaconda3/envs/spatial_inequ/lib/python3.10/site-packages/pymongo/pool.py:1331, in Pool.get_socket(self, all_credentials, handler)
#    1328 if self.enabled_for_cmap:
#    1329     listeners.publish_connection_check_out_started(self.address)
# -> 1331 sock_info = self._get_socket(all_credentials)
#    1332 if self.enabled_for_cmap:
#    1333     listeners.publish_connection_checked_out(
#    1334         self.address, sock_info.id)
#
# File ~/opt/anaconda3/envs/spatial_inequ/lib/python3.10/site-packages/pymongo/pool.py:1397, in Pool._get_socket(self, all_credentials)
#    1394         sock_info = self.sockets.popleft()
#    1395 except IndexError:
#    1396     # Can raise ConnectionFailure or CertificateError.
# -> 1397     sock_info = self.connect(all_credentials)
#    1398 else:
#    1399     if self._perished(sock_info):
#
# File ~/opt/anaconda3/envs/spatial_inequ/lib/python3.10/site-packages/pymongo/pool.py:1297, in Pool.connect(self, all_credentials)
#    1294         sock_info.hello(all_credentials)
#    1295         self.is_writable = sock_info.is_writable
# -> 1297     sock_info.check_auth(all_credentials)
#    1298 except BaseException:
#    1299     sock_info.close_socket(ConnectionClosedReason.ERROR)
#
# File ~/opt/anaconda3/envs/spatial_inequ/lib/python3.10/site-packages/pymongo/pool.py:820, in SocketInfo.check_auth(self, all_credentials)
#     817         self.authset.discard(credentials)
#     819     for credentials in cached - authset:
# --> 820         self.authenticate(credentials)
#     822 # CMAP spec says to publish the ready event only after authenticating
#     823 # the connection.
#     824 if not self.ready:
#
# File ~/opt/anaconda3/envs/spatial_inequ/lib/python3.10/site-packages/pymongo/pool.py:837, in SocketInfo.authenticate(self, credentials)
#     829 def authenticate(self, credentials):
#     830     """Log in to the server and store these credentials in `authset`.
#     831
#     832     Can raise ConnectionFailure or OperationFailure.
#    (...)
#     835       - `credentials`: A MongoCredential.
#     836     """
# --> 837     auth.authenticate(credentials, self)
#     838     self.authset.add(credentials)
#     839     # negotiated_mechanisms are no longer needed.
#
# File ~/opt/anaconda3/envs/spatial_inequ/lib/python3.10/site-packages/pymongo/auth.py:672, in authenticate(credentials, sock_info)
#     670 mechanism = credentials.mechanism
#     671 auth_func = _AUTH_MAP.get(mechanism)
# --> 672 auth_func(credentials, sock_info)
#
# File ~/opt/anaconda3/envs/spatial_inequ/lib/python3.10/site-packages/pymongo/auth.py:588, in _authenticate_default(credentials, sock_info)
#     584     mechs = sock_info.command(
#     585         source, cmd, publish_events=False).get(
#     586         'saslSupportedMechs', [])
#     587 if 'SCRAM-SHA-256' in mechs:
# --> 588     return _authenticate_scram(credentials, sock_info, 'SCRAM-SHA-256')
#     589 else:
#     590     return _authenticate_scram(credentials, sock_info, 'SCRAM-SHA-1')
#
# File ~/opt/anaconda3/envs/spatial_inequ/lib/python3.10/site-packages/pymongo/auth.py:333, in _authenticate_scram(credentials, sock_info, mechanism)
#     327 server_sig = standard_b64encode(
#     328     _hmac(server_key, auth_msg, digestmod).digest())
#     330 cmd = SON([('saslContinue', 1),
#     331            ('conversationId', res['conversationId']),
#     332            ('payload', Binary(client_final))])
# --> 333 res = sock_info.command(source, cmd)
#     335 parsed = _parse_scram_response(res['payload'])
#     336 if not compare_digest(parsed[b'v'], server_sig):
#
# File ~/opt/anaconda3/envs/spatial_inequ/lib/python3.10/site-packages/pymongo/pool.py:710, in SocketInfo.command(self, dbname, spec, secondary_ok, read_preference, codec_options, check, allowable_errors, check_keys, read_concern, write_concern, parse_write_concern_error, collation, session, client, retryable_write, publish_events, user_fields, exhaust_allowed)
#     708     self._raise_if_not_writable(unacknowledged)
#     709 try:
# --> 710     return command(self, dbname, spec, secondary_ok,
#     711                    self.is_mongos, read_preference, codec_options,
#     712                    session, client, check, allowable_errors,
#     713                    self.address, check_keys, listeners,
#     714                    self.max_bson_size, read_concern,
#     715                    parse_write_concern_error=parse_write_concern_error,
#     716                    collation=collation,
#     717                    compression_ctx=self.compression_context,
#     718                    use_op_msg=self.op_msg_enabled,
#     719                    unacknowledged=unacknowledged,
#     720                    user_fields=user_fields,
#     721                    exhaust_allowed=exhaust_allowed)
#     722 except (OperationFailure, NotPrimaryError):
#     723     raise
#
# File ~/opt/anaconda3/envs/spatial_inequ/lib/python3.10/site-packages/pymongo/network.py:158, in command(sock_info, dbname, spec, secondary_ok, is_mongos, read_preference, codec_options, session, client, check, allowable_errors, address, check_keys, listeners, max_bson_size, read_concern, parse_write_concern_error, collation, compression_ctx, use_op_msg, unacknowledged, user_fields, exhaust_allowed)
#     156             client._process_response(response_doc, session)
#     157         if check:
# --> 158             helpers._check_command_response(
#     159                 response_doc, sock_info.max_wire_version, allowable_errors,
#     160                 parse_write_concern_error=parse_write_concern_error)
#     161 except Exception as exc:
#     162     if publish:
#
# File ~/opt/anaconda3/envs/spatial_inequ/lib/python3.10/site-packages/pymongo/helpers.py:167, in _check_command_response(response, max_wire_version, allowable_errors, parse_write_concern_error)
#     164 elif code == 43:
#     165     raise CursorNotFound(errmsg, code, response, max_wire_version)
# --> 167 raise OperationFailure(errmsg, code, response, max_wire_version)
#
# OperationFailure: Authentication failed., full error: {'ok': 0.0, 'errmsg': 'Authentication failed.', 'code': 18, 'codeName': 'AuthenticationFailed'}

# %%
# Select specific columns only 
# You can select columns negatively by setting them to 0 = exclude them
# Or set the columns to 1 that you want to include
# You have to choose one or the other option

cursor = stack_overflow.find({},{'creation_date': 1, 'Country': 1,'tags':1, 'owner_user_id':1})

df = pd.DataFrame(list(cursor))
# Out:
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# File ~/opt/anaconda3/envs/spatial_inequ/lib/python3.10/site-packages/pymongo/pool.py:1394, in Pool._get_socket(self, all_credentials)
#    1393     with self.lock:
# -> 1394         sock_info = self.sockets.popleft()
#    1395 except IndexError:
#    1396     # Can raise ConnectionFailure or CertificateError.
#
# IndexError: pop from an empty deque
#
# During handling of the above exception, another exception occurred:
#
# OperationFailure                          Traceback (most recent call last)
# Input In [27], in <cell line: 8>()
#       1 # Select specific columns only
#       2 # You can select columns negatively by setting them to 0 = exclude them
#       3 # Or set the columns to 1 that you want to include
#       4 # You have to choose one or the other option
#       6 cursor = stack_overflow.find({},{'creation_date': 1, 'Country': 1,'tags':1, 'owner_user_id':1})
# ----> 8 df = pd.DataFrame(list(cursor))
#
# File ~/opt/anaconda3/envs/spatial_inequ/lib/python3.10/site-packages/pymongo/cursor.py:1238, in Cursor.next(self)
#    1236 if self.__empty:
#    1237     raise StopIteration
# -> 1238 if len(self.__data) or self._refresh():
#    1239     if self.__manipulate:
#    1240         _db = self.__collection.database
#
# File ~/opt/anaconda3/envs/spatial_inequ/lib/python3.10/site-packages/pymongo/cursor.py:1155, in Cursor._refresh(self)
#    1134         warnings.warn("using a min/max query operator without "
#    1135                       "specifying a Cursor.hint is deprecated. A "
#    1136                       "hint will be required when using min/max in "
#    1137                       "PyMongo 4.0",
#    1138                       DeprecationWarning, stacklevel=3)
#    1139     q = self._query_class(self.__query_flags,
#    1140                           self.__collection.database.name,
#    1141                           self.__collection.name,
#    (...)
#    1153                           self.__allow_disk_use,
#    1154                           self.__exhaust)
# -> 1155     self.__send_message(q)
#    1156 elif self.__id:  # Get More
#    1157     if self.__limit:
#
# File ~/opt/anaconda3/envs/spatial_inequ/lib/python3.10/site-packages/pymongo/cursor.py:1044, in Cursor.__send_message(self, operation)
#    1040     raise InvalidOperation(
#    1041         "exhaust cursors do not support auto encryption")
#    1043 try:
# -> 1044     response = client._run_operation(
#    1045         operation, self._unpack_response, address=self.__address)
#    1046 except OperationFailure as exc:
#    1047     if exc.code in _CURSOR_CLOSED_ERRORS or self.__exhaust:
#    1048         # Don't send killCursors because the cursor is already closed.
#
# File ~/opt/anaconda3/envs/spatial_inequ/lib/python3.10/site-packages/pymongo/mongo_client.py:1424, in MongoClient._run_operation(self, operation, unpack_res, address)
#    1419 def _cmd(session, server, sock_info, secondary_ok):
#    1420     return server.run_operation(
#    1421         sock_info, operation, secondary_ok, self._event_listeners,
#    1422         unpack_res)
# -> 1424 return self._retryable_read(
#    1425     _cmd, operation.read_preference, operation.session,
#    1426     address=address, retryable=isinstance(operation, message._Query))
#
# File ~/opt/anaconda3/envs/spatial_inequ/lib/python3.10/site-packages/pymongo/mongo_client.py:1518, in MongoClient._retryable_read(self, func, read_pref, session, address, retryable)
#    1516 if not server.description.retryable_reads_supported:
#    1517     retryable = False
# -> 1518 with self._secondaryok_for_server(
#    1519         read_pref, server, session) as (
#    1520                 sock_info, secondary_ok):
#    1521     if retrying and not retryable:
#    1522         # A retry is not possible because this server does
#    1523         # not support retryable reads, raise the last error.
#    1524         raise last_error
#
# File ~/opt/anaconda3/envs/spatial_inequ/lib/python3.10/contextlib.py:135, in _GeneratorContextManager.__enter__(self)
#     133 del self.args, self.kwds, self.func
#     134 try:
# --> 135     return next(self.gen)
#     136 except StopIteration:
#     137     raise RuntimeError("generator didn't yield") from None
#
# File ~/opt/anaconda3/envs/spatial_inequ/lib/python3.10/site-packages/pymongo/mongo_client.py:1371, in MongoClient._secondaryok_for_server(self, read_preference, server, session)
#    1368 topology = self._get_topology()
#    1369 single = topology.description.topology_type == TOPOLOGY_TYPE.Single
# -> 1371 with self._get_socket(server, session) as sock_info:
#    1372     secondary_ok = (single and not sock_info.is_mongos) or (
#    1373         read_preference != ReadPreference.PRIMARY)
#    1374     yield sock_info, secondary_ok
#
# File ~/opt/anaconda3/envs/spatial_inequ/lib/python3.10/contextlib.py:135, in _GeneratorContextManager.__enter__(self)
#     133 del self.args, self.kwds, self.func
#     134 try:
# --> 135     return next(self.gen)
#     136 except StopIteration:
#     137     raise RuntimeError("generator didn't yield") from None
#
# File ~/opt/anaconda3/envs/spatial_inequ/lib/python3.10/site-packages/pymongo/mongo_client.py:1308, in MongoClient._get_socket(self, server, session)
#    1306     yield session._pinned_connection
#    1307     return
# -> 1308 with server.get_socket(
#    1309         self.__all_credentials, handler=err_handler) as sock_info:
#    1310     # Pin this session to the selected server or connection.
#    1311     if (in_txn and server.description.server_type in (
#    1312             SERVER_TYPE.Mongos, SERVER_TYPE.LoadBalancer)):
#    1313         session._pin(server, sock_info)
#
# File ~/opt/anaconda3/envs/spatial_inequ/lib/python3.10/contextlib.py:135, in _GeneratorContextManager.__enter__(self)
#     133 del self.args, self.kwds, self.func
#     134 try:
# --> 135     return next(self.gen)
#     136 except StopIteration:
#     137     raise RuntimeError("generator didn't yield") from None
#
# File ~/opt/anaconda3/envs/spatial_inequ/lib/python3.10/site-packages/pymongo/pool.py:1331, in Pool.get_socket(self, all_credentials, handler)
#    1328 if self.enabled_for_cmap:
#    1329     listeners.publish_connection_check_out_started(self.address)
# -> 1331 sock_info = self._get_socket(all_credentials)
#    1332 if self.enabled_for_cmap:
#    1333     listeners.publish_connection_checked_out(
#    1334         self.address, sock_info.id)
#
# File ~/opt/anaconda3/envs/spatial_inequ/lib/python3.10/site-packages/pymongo/pool.py:1397, in Pool._get_socket(self, all_credentials)
#    1394         sock_info = self.sockets.popleft()
#    1395 except IndexError:
#    1396     # Can raise ConnectionFailure or CertificateError.
# -> 1397     sock_info = self.connect(all_credentials)
#    1398 else:
#    1399     if self._perished(sock_info):
#
# File ~/opt/anaconda3/envs/spatial_inequ/lib/python3.10/site-packages/pymongo/pool.py:1297, in Pool.connect(self, all_credentials)
#    1294         sock_info.hello(all_credentials)
#    1295         self.is_writable = sock_info.is_writable
# -> 1297     sock_info.check_auth(all_credentials)
#    1298 except BaseException:
#    1299     sock_info.close_socket(ConnectionClosedReason.ERROR)
#
# File ~/opt/anaconda3/envs/spatial_inequ/lib/python3.10/site-packages/pymongo/pool.py:820, in SocketInfo.check_auth(self, all_credentials)
#     817         self.authset.discard(credentials)
#     819     for credentials in cached - authset:
# --> 820         self.authenticate(credentials)
#     822 # CMAP spec says to publish the ready event only after authenticating
#     823 # the connection.
#     824 if not self.ready:
#
# File ~/opt/anaconda3/envs/spatial_inequ/lib/python3.10/site-packages/pymongo/pool.py:837, in SocketInfo.authenticate(self, credentials)
#     829 def authenticate(self, credentials):
#     830     """Log in to the server and store these credentials in `authset`.
#     831
#     832     Can raise ConnectionFailure or OperationFailure.
#    (...)
#     835       - `credentials`: A MongoCredential.
#     836     """
# --> 837     auth.authenticate(credentials, self)
#     838     self.authset.add(credentials)
#     839     # negotiated_mechanisms are no longer needed.
#
# File ~/opt/anaconda3/envs/spatial_inequ/lib/python3.10/site-packages/pymongo/auth.py:672, in authenticate(credentials, sock_info)
#     670 mechanism = credentials.mechanism
#     671 auth_func = _AUTH_MAP.get(mechanism)
# --> 672 auth_func(credentials, sock_info)
#
# File ~/opt/anaconda3/envs/spatial_inequ/lib/python3.10/site-packages/pymongo/auth.py:588, in _authenticate_default(credentials, sock_info)
#     584     mechs = sock_info.command(
#     585         source, cmd, publish_events=False).get(
#     586         'saslSupportedMechs', [])
#     587 if 'SCRAM-SHA-256' in mechs:
# --> 588     return _authenticate_scram(credentials, sock_info, 'SCRAM-SHA-256')
#     589 else:
#     590     return _authenticate_scram(credentials, sock_info, 'SCRAM-SHA-1')
#
# File ~/opt/anaconda3/envs/spatial_inequ/lib/python3.10/site-packages/pymongo/auth.py:333, in _authenticate_scram(credentials, sock_info, mechanism)
#     327 server_sig = standard_b64encode(
#     328     _hmac(server_key, auth_msg, digestmod).digest())
#     330 cmd = SON([('saslContinue', 1),
#     331            ('conversationId', res['conversationId']),
#     332            ('payload', Binary(client_final))])
# --> 333 res = sock_info.command(source, cmd)
#     335 parsed = _parse_scram_response(res['payload'])
#     336 if not compare_digest(parsed[b'v'], server_sig):
#
# File ~/opt/anaconda3/envs/spatial_inequ/lib/python3.10/site-packages/pymongo/pool.py:710, in SocketInfo.command(self, dbname, spec, secondary_ok, read_preference, codec_options, check, allowable_errors, check_keys, read_concern, write_concern, parse_write_concern_error, collation, session, client, retryable_write, publish_events, user_fields, exhaust_allowed)
#     708     self._raise_if_not_writable(unacknowledged)
#     709 try:
# --> 710     return command(self, dbname, spec, secondary_ok,
#     711                    self.is_mongos, read_preference, codec_options,
#     712                    session, client, check, allowable_errors,
#     713                    self.address, check_keys, listeners,
#     714                    self.max_bson_size, read_concern,
#     715                    parse_write_concern_error=parse_write_concern_error,
#     716                    collation=collation,
#     717                    compression_ctx=self.compression_context,
#     718                    use_op_msg=self.op_msg_enabled,
#     719                    unacknowledged=unacknowledged,
#     720                    user_fields=user_fields,
#     721                    exhaust_allowed=exhaust_allowed)
#     722 except (OperationFailure, NotPrimaryError):
#     723     raise
#
# File ~/opt/anaconda3/envs/spatial_inequ/lib/python3.10/site-packages/pymongo/network.py:158, in command(sock_info, dbname, spec, secondary_ok, is_mongos, read_preference, codec_options, session, client, check, allowable_errors, address, check_keys, listeners, max_bson_size, read_concern, parse_write_concern_error, collation, compression_ctx, use_op_msg, unacknowledged, user_fields, exhaust_allowed)
#     156             client._process_response(response_doc, session)
#     157         if check:
# --> 158             helpers._check_command_response(
#     159                 response_doc, sock_info.max_wire_version, allowable_errors,
#     160                 parse_write_concern_error=parse_write_concern_error)
#     161 except Exception as exc:
#     162     if publish:
#
# File ~/opt/anaconda3/envs/spatial_inequ/lib/python3.10/site-packages/pymongo/helpers.py:167, in _check_command_response(response, max_wire_version, allowable_errors, parse_write_concern_error)
#     164 elif code == 43:
#     165     raise CursorNotFound(errmsg, code, response, max_wire_version)
# --> 167 raise OperationFailure(errmsg, code, response, max_wire_version)
#
# OperationFailure: Authentication failed., full error: {'ok': 0.0, 'errmsg': 'Authentication failed.', 'code': 18, 'codeName': 'AuthenticationFailed'}
